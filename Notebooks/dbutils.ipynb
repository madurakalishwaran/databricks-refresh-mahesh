# %%
# %sql
SELECT * FROM workspace.food_delivery.gold_restaurant_daily_sales ORDER BY order_date DESC;
SELECT COUNT(*) FROM workspace.food_delivery.bronze_orders;
--395
SELECT COUNT(*) FROM workspace.food_delivery.silver_orders_clean;
--354
SELECT COUNT(*) FROM workspace.food_delivery.gold_restaurant_daily_sales;
--30
SELECT COUNT(DISTINCT ORDER_DATE) FROM workspace.food_delivery.gold_restaurant_daily_sales;
--3
select count(distinct restaurant_id) from workspace.food_delivery.silver_orders_clean;
--10
